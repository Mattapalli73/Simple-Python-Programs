# %%
I=int(input("Enter the any Integer : "))
if I%2==0:
    print("The Given Number is Even")
else:
    print("The Given Number is Odd")
# Out:
# Enter the any Integer :  15
# The Given Number is Odd
