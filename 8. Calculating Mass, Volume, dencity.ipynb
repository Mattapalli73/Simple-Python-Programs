# %%
mdv=input("Enter what you want to caliculate")
if mdv=='m':
    d=float(input("Enter value d"))
    v=float(input("Enter value v"))
    print("mass m is:",d*v)
elif mdv=='d':
    m=float(input("Enter value m"))
    v=float(input("Enter value v"))
    print("mass m is:",m/v)
elif mdv=='v':
    m=float(input("Enter value m"))
    d=float(input("Enter value d"))
    print("mass m is:",m/d)
# Out:
# Enter what you want to caliculate:
# Enter what you want to caliculate v
# Enter value m 10
# Enter value d 10
# mass m is: 1.0
