# %%
x=float(input("Enter the coordinate of X point"))
y=float(input("Enter the coordinate of Y point"))
if x>0 and y>0:
    print("the given co ordinates are in first Quadrant")
elif x>0 and y<0:
    print("the given co ordinates are in second Quadrant")
elif x<0 and y<0:
    print("the given co ordinates are in Third Quadrant")
elif x>0 and y>0:
    print("the given co ordinates are in fourth Quadrant")
# Out:
# Enter the coordinate of X point 10
# Enter the coordinate of Y point 10
# the given co ordinates are in first Quadrant
