# %%
a=int(input("Enter any number a:"))
b=int(input("Enter any number b:"))
c=int(input("Enter any number c:"))
if a == b & b == c & a == c:
    print("The given Integers are same")
elif b <= a >= c:
    print("the Greatest Number is:", a)
elif a <= b >= c:
    print("the Greatest Number is:", b)
elif a <= c >= b:
    print("the Greatest Number is:", c)
# Out:
# Enter any number a: 10
# Enter any number b: 10
# Enter any number c: 10
# The given Integers are same
