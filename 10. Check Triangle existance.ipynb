# %%
a=float(input("Enter one side of a triangle"))
b=float(input("Enter one side of b triangle"))
c=float(input("Enter one side of c triangle"))
if a+b>c and a+c>b and b+c>a:
    print("The triangle is Exists")
else:
    print("The triagle never Exists")
# Out:
# Enter one side of a triangle 1
# Enter one side of b triangle 1
# Enter one side of c triangle 4
# The triagle never Exists
